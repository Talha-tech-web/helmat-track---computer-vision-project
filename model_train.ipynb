# %%
pip install torch

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.9 MB/s eta 0:00:00
# ...

# %%
pip install pytorch
pip install ultralytics

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Thu Apr  2 09:02:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8             13W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%writefile /content/drive/MyDrive/license/data.yaml
# train: /content/drive/MyDrive/license/train
# val: /content/drive/MyDrive/license/valid
#
# nc: 2
# names: ['With Helmet', 'Without Helmet']
# Out:
# Overwriting /content/drive/MyDrive/license/data.yaml

# %%
# !yolo task=detect mode=train model=yolov8l.pt \
data=/content/drive/MyDrive/license/data.yaml \
epochs=50 imgsz=550
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
