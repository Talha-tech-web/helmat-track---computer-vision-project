# %%
import cv2
import math
import cvzone
from ultralytics import YOLO

# %%
# Load YOLO model with custom weights in which you train your model
yolo_model = YOLO(r"D:\work\projects\computer vision\license detection\bike helmet\weight\best.pt")

class_labels = ['With Helmet', 'Without Helmet']

# %%
# Load the image
img1 = cv2.imread(r"D:\work\projects\computer vision\license detection\bike helmet\media\riders_1.jpg")
img2 = cv2.imread(r"D:\work\projects\computer vision\license detection\bike helmet\media\riders_2.jpg")
img3 = cv2.imread(r"D:\work\projects\computer vision\license detection\bike helmet\media\riders_3.jpg")
img4 = cv2.imread(r"D:\work\projects\computer vision\license detection\bike helmet\media\riders_4.jpg")

# %%
img=img1

# %%
# Perform object detection
results = yolo_model(img)
# Out:
# 0: 416x608 7 With Helmets, 1138.1ms
# Speed: 27.9ms preprocess, 1138.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 608)

# %%
# Loop through the detections and draw bounding boxes
for r in results:
    boxes = r.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

        w, h = x2 - x1, y2 - y1
        cvzone.cornerRect(img, (x1, y1, w, h))
        conf = math.ceil((box.conf[0] * 100)) / 100
        cls = int(box.cls[0])

        if conf > 0.1:
            cvzone.putTextRect(img, f'{class_labels[cls]} {conf}', (x1, y1 - 10), scale=0.8, thickness=1, colorR=(255, 0, 0))

# %%
# Display the image with detections
cv2.imshow("Image", img)

# Close window when 'q' button is pressed
while True:
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
cv2.waitKey(0)

# %%
import cv2
import math
import cvzone
from ultralytics import YOLO
yolo_model = YOLO(r"weight\best.pt") # Load YOLO model
class_labels = ['With Helmet', 'Without Helmet']
img = cv2.imread(r"media\riders_5.jpg")
img=cv2.resize(img,(800,600))
results = yolo_model(img) # Perform object detection
for r in results: # Loop through the detections and draw bounding boxes
    boxes = r.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2 - x1, y2 - y1
        cvzone.cornerRect(img, (x1, y1, w, h))
        conf = math.ceil((box.conf[0] * 100)) / 100
        cls = int(box.cls[0])
        if conf > 0.1:
            cvzone.putTextRect(img, f'{class_labels[cls]} {conf}', (x1, y1 - 10),
            scale=0.8, thickness=1, colorR=(255, 0, 0))
cv2.imshow("Image", img)  # Display the image with detections
while True:
    if cv2.waitKey(0) & 0xFF == ord('p'):
        break
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 480x608 9 With Helmets, 1763.4ms
# Speed: 25.8ms preprocess, 1763.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 608)

# %% [markdown]
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0,
# box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0,
# copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/license/data.yaml, degrees=0.0,
# deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None,
# epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None,
# half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=550, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None,
# lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0,
# multi_scale=0.0, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True,
# patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False,
# resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2,
# save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True,
# show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect,
# time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1,
# warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5584342  ultralytics.nn.modules.head.Detect           [2, 16, None, [256, 512, 512]]
# Model summary: 210 layers, 43,631,382 parameters, 43,631,366 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[550] must be multiple of max stride 32, updating to [576]
# train: Fast image access ✅ (ping: 0.6±0.2 ms, read: 16.5±8.1 MB/s, size: 29.8 KB)
# train: Scanning /content/drive/MyDrive/license/train/labels.cache... 3546 images, 129 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3546/3546 495.8Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3),
# CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 4.4±8.0 ms, read: 4.6±3.4 MB/s, size: 33.1 KB)
# val: Scanning /content/drive/MyDrive/license/valid/labels.cache... 126 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 126/126 4.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# Image sizes 576 train, 576 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 50 epochs...

# %% [markdown]
#  Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      7.56G      1.844      1.917      1.718         61        576: 100% ━━━━━━━━━━━━ 222/222 10.1s/it 37:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                    all        126        299      0.188      0.308      0.146     0.0577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      8.21G      1.809      1.706      1.733         85        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.8it/s 2.2s
#                    all        126        299      0.387      0.451      0.352      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      7.82G      1.782      1.676       1.72         52        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.517      0.498      0.459       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50       7.7G      1.725      1.563      1.682         56        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.518      0.495      0.484      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      8.18G      1.683      1.455       1.65         50        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.2s
#                    all        126        299      0.542      0.588       0.56       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      7.68G      1.643      1.353      1.623         64        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.4s
#                    all        126        299      0.534      0.394      0.384      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      8.14G        1.6      1.275      1.597         73        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.667      0.607      0.591      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      7.74G      1.587      1.239      1.581         32        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        126        299      0.692      0.682       0.71       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      8.13G      1.562      1.192      1.566         53        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.673      0.638      0.632      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50       7.7G      1.522      1.131      1.542         72        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.8it/s 2.2s
#                    all        126        299      0.689      0.654       0.69      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       8.1G      1.511      1.106       1.53         63        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.677       0.56      0.582      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       7.7G      1.496      1.068      1.524         56        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.8it/s 2.3s
#                    all        126        299      0.657      0.642      0.663      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      8.12G      1.467      1.035      1.508         77        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.659      0.666       0.64      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.73G      1.455      1.001       1.49         79        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.8it/s 2.3s
#                    all        126        299      0.699      0.765       0.76      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      8.13G      1.432     0.9897      1.473         53        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.4s
#                    all        126        299      0.734      0.712      0.737      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      7.72G      1.426     0.9597      1.467         46        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.2s
#                    all        126        299      0.712      0.768      0.718      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      8.12G      1.402     0.9352      1.452         59        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.712      0.753      0.751      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      7.71G      1.388     0.9283      1.445         62        576: 100% ━━━━━━━━━━━━ 222/222 1.5it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        126        299      0.873      0.801      0.868      0.429
#
# 50 epochs completed in 2.719 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 87.6MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 87.6MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0s/it 4.1s
#                    all        126        299      0.837      0.822      0.862      0.437
#            With Helmet         88        184      0.882      0.897      0.922      0.479
#         Without Helmet         53        115      0.791      0.748      0.802      0.395
# Speed: 0.2ms preprocess, 15.0ms inference, 0.0ms loss, 6.8ms postprocess per image
# Results saved to /content/runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import cv2
import math
import cvzone
from ultralytics import YOLO
cap = cv2.VideoCapture(r"media\demo.mp4")
model = YOLO(r"weight\best.pt")
classNames = ['With Helmet', 'Without Helmet']
while cap.isOpened():
    r, f = cap.read()
    if r==True:
        results = model(f, stream=True)
        for r in results:
            boxes = r.boxes
            for box in boxes:
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                w, h = x2 - x1, y2 - y1
                cvzone.cornerRect(f, (x1, y1, w, h))
                conf = math.ceil((box.conf[0] * 100)) / 100
                cls = int(box.cls[0])
                cvzone.putTextRect(f, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
        cv2.imshow("Talha", f)
        if cv2.waitKey(15) & 0xff == ord('p'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 1 With Helmet, 1 Without Helmet, 836.2ms
# Speed: 27.2ms preprocess, 836.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 917.7ms
# Speed: 6.9ms preprocess, 917.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 With Helmets, 2 Without Helmets, 809.0ms
# Speed: 6.2ms preprocess, 809.0ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 With Helmets, 2 Without Helmets, 797.7ms
# Speed: 6.6ms preprocess, 797.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 886.8ms
# Speed: 4.8ms preprocess, 886.8ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 1284.5ms
# Speed: 6.1ms preprocess, 1284.5ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 608)
#
# ...

# %%
import cv2
import math
import cvzone
from ultralytics import YOLO

cap = cv2.VideoCapture(r"media\demo.mp4")
model = YOLO(r"weight\best.pt")

classNames = ['With Helmet', 'Without Helmet']

fps = cap.get(cv2.CAP_PROP_FPS)
delay = int(500 / fps)

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        print("Video Finished ✅")
        break

    # Resize for speed
    frame = cv2.resize(frame, (640, 360))

    results = model(frame)

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            w, h = x2 - x1, y2 - y1

            cvzone.cornerRect(frame, (x1, y1, w, h))

            conf = math.ceil(box.conf[0] * 100) / 100
            cls = int(box.cls[0])

            cvzone.putTextRect(
                frame,
                f'{classNames[cls]} {conf}',
                (max(0, x1), max(35, y1)),
                scale=1,
                thickness=1
            )

    cv2.imshow("Talha", frame)

    if cv2.waitKey(delay) & 0xFF == ord('p'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 1 With Helmet, 2 Without Helmets, 921.6ms
# Speed: 4.5ms preprocess, 921.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 924.7ms
# Speed: 6.9ms preprocess, 924.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 986.1ms
# Speed: 5.1ms preprocess, 986.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 850.0ms
# Speed: 3.9ms preprocess, 850.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 960.4ms
# Speed: 4.1ms preprocess, 960.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 1059.2ms
# Speed: 5.1ms preprocess, 1059.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 With Helmet, 2 Without Helmets, 852.3ms
# ...
